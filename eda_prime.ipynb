# %%
from munger import Munger
mngr = Munger()

# %%
df_meta, df_features = mngr.munge()
# Out:
# Returning meta_data dataframe followed by feature_space_dataframe for  data/4096_vals.csv

# %%
df_meta.head(2)
# Out:
#                    CID Category SubCategory HeelHeight   Insole  Closure  \
# CID
# 100627-72    100627-72    Shoes     Oxfords        NaN  Leather  Lace up
# 100627-255  100627-255    Shoes     Oxfords        NaN  Leather  Lace up
#
#            Gender Material              ToeStyle  \
# CID
# 100627-72     Men  Leather  Capped Toe;Round Toe
# 100627-255    Men  Leather  Capped Toe;Round Toe
#
#                                                      img_path
# CID
# 100627-72   data/ut-zap50k-images/Shoes/Oxfords/Bostonian/...
# 100627-255  data/ut-zap50k-images/Shoes/Oxfords/Bostonian/...

# %%
df_features.head(2)
# Out:
#               0    1    2         3         4         5         6         7  \
# CID
# 100627-72   0.0  0.0  0.0  0.000000  0.797750  1.912231  0.460728  0.388322
# 100627-255  0.0  0.0  0.0  0.407239  0.530932  0.000000  0.000000  0.000000
#
#                    8    9    ...         4086      4087      4088  4089  \
# CID                          ...
# 100627-72   0.000000  0.0    ...     0.000000  0.168993  0.000000   0.0
# 100627-255  0.608484  0.0    ...     0.651812  0.793880  1.848819   0.0
#
#                 4090      4091      4092      4093      4094      4095
# CID
# 100627-72   0.760338  0.000000  0.000000  0.000000  0.902843  0.732134
# 100627-255  0.000000  0.242023  0.333321  0.398977  0.000000  0.000000
#
# [2 rows x 4096 columns]

# %%
from recommender import Recommender
recommender = Recommender(df_features, df_meta['img_path'], verbose=False)

# %%
target_shoe = df_meta['CID'][23]
recommender.display_target(target_shoe
# Out:
# '101191-24883'

# %%
recommender.recommend_k(10, '100627-72')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10B9B4588>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C048>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C3C8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C438>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C4A8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C518>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C588>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C630>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C6A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x10F64C710>
